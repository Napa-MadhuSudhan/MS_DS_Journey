# %% [markdown]
# <a href="https://colab.research.google.com/github/Napa-MadhuSudhan/MS_DS_Journey/blob/main/EDA/Zomato.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Zomato Dataset Explorative Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/zomato.csv', encoding='latin-1')

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()

# %%
[features for features in df.columns if df[features].isnull().sum()>0]

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
df_country = pd.read_excel('/content/Country-Code.xlsx')

# %%
df_country.head()

# %%
final_df = pd.merge(df, df_country, on='Country Code',how = 'left')

# %%
final_df.head()

# %% [markdown]
# ## Top 3 countries which have restaurants in the Zomato

# %%
final_df['Country'].value_counts()[:3].plot(kind='pie', figsize=(9,10),autopct='%1.2f%%')

# %% [markdown]
# observation : Zomato have maximum busisness share in India and very nominal about business in the rest of India.

# %%
final_df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
